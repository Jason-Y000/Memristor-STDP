# %%
import os
import numpy as np
import pandas as pd
import scipy.signal as sg
import matplotlib.pyplot as plt 
from matplotlib.ticker import AutoMinorLocator

# %% [markdown]
# # Noise Analysis

# %%
# Noise Baselines
pth0 = '/Users/jasonyuan/Desktop/Kherani Lab/Memristor/Keithley Data/Au Vertical/February 19/STDP_Open_Noise_Baseline.xls'
pth1 = '/Users/jasonyuan/Desktop/Kherani Lab/Memristor/Keithley Data/Au Vertical/February 19/STDP_Open_Noise_Baseline_Seq8.xls'
pth2 = '/Users/jasonyuan/Desktop/Kherani Lab/Memristor/Keithley Data/Au Vertical/February 19/STDP_Open_Noise_Baseline_Seq7_Seq8.xls'
pth3 = '/Users/jasonyuan/Desktop/Kherani Lab/Memristor/Keithley Data/Au Vertical/February 19/STDP_Open_Noise_Baseline_Seq6.xls'

df_noise0 = pd.read_excel(pth0, sheet_name=None)
df_noise1 = pd.read_excel(pth1, sheet_name=None)
df_noise2 = pd.read_excel(pth2, sheet_name=None)
df_noise3 = pd.read_excel(pth3, sheet_name=None)
# Out:
# WARNING *** file size (8013120) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (7994124) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (12474664) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
# %matplotlib notebook

fig0 = plt.figure(1,figsize=(12,6))
ax = fig0.add_subplot(1,2,1)
ax1 = fig0.add_subplot(1,2,2)
n = 0
for sheet in df_noise0.keys():
    if sheet == 'Calc' or sheet == 'Settings':
        continue 
    else:
        vals = df_noise0[sheet][['TimeOutput','VMeasCh1','IMeasCh1']].to_numpy()
        ax.plot(vals[:,0], vals[:,1])
        ax1.plot(vals[:,0],vals[:,2],label='Run {}'.format(n))
        n += 1
ax.grid(linestyle='--',color='silver')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Voltage (V)')

ax1.grid(linestyle='--',color='silver')
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Current (A)')
ax1.legend(loc='best',ncol=n//4)

plt.show()

# P1: t1 = 0.0002, t2 = 0.0010
# P2: t1 = 0.0166, t2 = 0.0174
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
# %matplotlib notebook

fig1 = plt.figure(2,figsize=(12,6))
ax = fig1.add_subplot(1,2,1)
ax1 = fig1.add_subplot(1,2,2)
n = 0
for sheet in df_noise1.keys():
    if sheet == 'Calc' or sheet == 'Settings':
        continue 
    else:
        vals = df_noise1[sheet][['TimeOutput','VMeasCh1','IMeasCh1']].to_numpy()
        ax.plot(vals[:,0], vals[:,1])
        ax1.plot(vals[:,0],vals[:,2],label='Run {}'.format(n))
        n += 1
ax.grid(linestyle='--',color='silver')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Voltage (V)')

ax1.grid(linestyle='--',color='silver')
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Current (A)')
ax1.legend(loc='best',ncol=n//4)

plt.show()

# P1: t1 = 0.0002, t2 = 0.0010
# P2: t1 = 0.02138, t2 = 0.02225
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
# %matplotlib notebook

fig2 = plt.figure(3,figsize=(12,6))
ax = fig2.add_subplot(1,2,1)
ax1 = fig2.add_subplot(1,2,2)
n = 0
for sheet in df_noise2.keys():
    if sheet == 'Calc' or sheet == 'Settings':
        continue 
    else:
        vals = df_noise2[sheet][['TimeOutput','VMeasCh1','IMeasCh1']].to_numpy()
        ax.plot(vals[:,0], vals[:,1])
        ax1.plot(vals[:,0],vals[:,2],label='Run {}'.format(n))
        n += 1
ax.grid(linestyle='--',color='silver')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Voltage (V)')

ax1.grid(linestyle='--',color='silver')
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Current (A)')
ax1.legend(loc='best',ncol=n//4)

plt.show()

# P1: t1 = 0.0002, t2 = 0.0010
# P2: t1 = 0.01640, t2 = 0.01725
# P3: t1 = 0.03775, t2 = 0.0383
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
# %matplotlib notebook

fig3 = plt.figure(4,figsize=(12,6))
ax = fig3.add_subplot(1,2,1)
ax1 = fig3.add_subplot(1,2,2)
n = 0
for sheet in df_noise3.keys():
    if sheet == 'Calc' or sheet == 'Settings':
        continue 
    else:
        vals = df_noise3[sheet][['TimeOutput','VMeasCh1','IMeasCh1']].to_numpy()
        ax.plot(vals[:,0], vals[:,1])
        ax1.plot(vals[:,0],vals[:,2],label='Run {}'.format(n))
        n += 1
ax.grid(linestyle='--',color='silver')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Voltage (V)')

ax1.grid(linestyle='--',color='silver')
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Current (A)')
ax1.legend(loc='best',ncol=n//4)

plt.show()

# P1: t1 = 0.0002, t2 = 0.0010
# P2: t1 = 0.01635, t2 = 0.01725
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
# %matplotlib inline
# Get the noise average for df_noise0

t1_1 = 0.0001
t1_2 = 0.0010
t2_1 = 0.0166
t2_2 = 0.0174
n = 0

firstP = []
secondP = []
diffP = []

for sheet in df_noise0.keys():
    if sheet == 'Calc' or sheet == 'Settings':
        continue 
    else:
        dat0 = df_noise0[sheet][['TimeOutput','VMeasCh1','IMeasCh1']].to_numpy()

        idx1_1 = -1
        idx1_2 = -1
        idx2_1 = -1
        idx2_2 = -1
        
        for i in range(dat0.shape[0]):
            if dat0[i,0] >= t1_1 and dat0[i,0] < t1_2 and idx1_1 == -1:
                idx1_1 = i
            
            if dat0[i,0] >= t1_2 and idx1_2 == -1:
                idx1_2 = i

            if dat0[i,0] >= t2_1 and dat0[i,0] < t2_2 and idx2_1 == -1:
                idx2_1 = i

            if dat0[i,0] >= t2_2 and idx2_2 == -1:
                idx2_2 = i

        avg1 = np.average(dat0[idx1_1:idx1_2,2])
        avg2 = np.average(dat0[idx2_1:idx2_2,2])

        firstP.append(avg1)
        secondP.append(avg2)
        diffP.append(avg2-avg1)
        print(n, avg1, avg2, avg2-avg1)
        
        n += 1

plt.figure()
plt.subplot(1,3,1)
plt.hist(firstP, 10)
plt.subplot(1,3,2)
plt.hist(secondP,10)
plt.subplot(1,3,3)
plt.hist(diffP, 10)
plt.show()
# Out:
# 0 1.6955373681370207e-07 2.7453863170293044e-07 1.0498489488922837e-07
# 1 2.1388764241102545e-07 2.127402360471256e-07 -1.1474063638998536e-09
# 2 1.0596542403792382e-07 2.335332834220689e-07 1.2756785938414507e-07
# 3 2.1200696817150595e-07 3.0922438239357717e-07 9.721741422207122e-08
# 4 1.4949063100859197e-07 2.2776151321491974e-07 7.827088220632777e-08
# 5 2.0678085367579065e-07 2.7878381842099326e-07 7.200296474520261e-08
# 6 2.5805716601652954e-07 3.1908044446285834e-07 6.10232784463288e-08
# 7 2.8020890170733914e-07 3.730059081617843e-07 9.279700645444517e-08
# 8 1.6484429969249612e-07 2.3653638706643996e-07 7.169208737394385e-08
# 9 1.84273513232118e-07 2.906327105909196e-07 1.063591973588016e-07
# 10 1.7398297209883208e-07 2.6012432902342825e-07 8.614135692459618e-08
# 11 2.0305835561561103e-07 2.7175580086002665e-07 6.869744524441561e-08
# 12 2.398633470041804e-07 3.0756015987167163e-07 6.769681286749121e-08
# ...

# %%
# %matplotlib inline
# Get the noise average for df_noise1

t1_1 = 0.0001
t1_2 = 0.0010
t2_1 = 0.02138
t2_2 = 0.02225
n = 0

firstP_1 = []
secondP_1 = []
diffP_1 = []

for sheet in df_noise1.keys():
    if sheet == 'Calc' or sheet == 'Settings':
        continue 
    else:
        dat1 = df_noise1[sheet][['TimeOutput','VMeasCh1','IMeasCh1']].to_numpy()

        idx1_1 = -1
        idx1_2 = -1
        idx2_1 = -1
        idx2_2 = -1
        
        for i in range(dat1.shape[0]):
            if dat1[i,0] >= t1_1 and dat1[i,0] < t1_2 and idx1_1 == -1:
                idx1_1 = i
            
            if dat1[i,0] >= t1_2 and idx1_2 == -1:
                idx1_2 = i

            if dat1[i,0] >= t2_1 and dat1[i,0] < t2_2 and idx2_1 == -1:
                idx2_1 = i

            if dat1[i,0] >= t2_2 and idx2_2 == -1:
                idx2_2 = i

        avg1 = np.average(dat1[idx1_1:idx1_2,2])
        avg2 = np.average(dat1[idx2_1:idx2_2,2])

        firstP_1.append(avg1)
        secondP_1.append(avg2)
        diffP_1.append(avg2-avg1)
        print(n, avg1, avg2, avg2-avg1)
        
        n += 1

plt.figure()
plt.subplot(1,3,1)
plt.hist(firstP_1, 10)
plt.subplot(1,3,2)
plt.hist(secondP_1,10)
plt.subplot(1,3,3)
plt.hist(diffP_1, 10)
plt.show()
# Out:
# 0 3.236199215095326e-07 3.8495248636648334e-07 6.133256485695077e-08
# 1 2.0603458488643867e-07 2.590802217505217e-07 5.3045636864083046e-08
# 2 2.682581583002275e-07 3.5502284635429653e-07 8.676468805406905e-08
# 3 2.819293099420861e-07 3.404723320732211e-07 5.854302213113499e-08
# 4 3.499844699206278e-07 3.9567314194680057e-07 4.568867202617277e-08
# 5 3.034207612984119e-07 3.1725134819481433e-07 1.3830586896402442e-08
# 6 2.633455335043777e-07 3.6103745930936243e-07 9.769192580498471e-08

# %%
# %matplotlib inline
# Get the noise average for df_noise2

# P1: t1 = 0.0002, t2 = 0.0010
# P2: t1 = 0.01640, t2 = 0.01725
# P3: t1 = 0.03775, t2 = 0.0383

t1_1 = 0.0001
t1_2 = 0.0010
t2_1 = 0.01640
t2_2 = 0.01725
t31 = 0.03775
t32 = 0.03830
n = 0

firstP_2 = []
secondP_2 = []
thirdP_2 = []
diffP_21 = []
diffP_22 = []

for sheet in df_noise2.keys():
    if sheet == 'Calc' or sheet == 'Settings':
        continue 
    else:
        dat1 = df_noise2[sheet][['TimeOutput','VMeasCh1','IMeasCh1']].to_numpy()

        idx1_1 = -1
        idx1_2 = -1
        idx2_1 = -1
        idx2_2 = -1
        idx31 = -1
        idx32 = -1
        
        for i in range(dat1.shape[0]):
            if dat1[i,0] >= t1_1 and dat1[i,0] < t1_2 and idx1_1 == -1:
                idx1_1 = i
            
            if dat1[i,0] >= t1_2 and idx1_2 == -1:
                idx1_2 = i

            if dat1[i,0] >= t2_1 and dat1[i,0] < t2_2 and idx2_1 == -1:
                idx2_1 = i

            if dat1[i,0] >= t2_2 and idx2_2 == -1:
                idx2_2 = i
            
            if dat1[i,0] >= t31 and dat1[i,0] < t32 and idx31 == -1:
                idx31 = i

            if dat1[i,0] >= t32 and idx32 == -1:
                idx32 = i

        avg1 = np.average(dat1[idx1_1:idx1_2,2])
        avg2 = np.average(dat1[idx2_1:idx2_2,2])
        avg3 = np.average(dat1[idx31:idx32,2])

        firstP_2.append(avg1)
        secondP_2.append(avg2)
        thirdP_2.append(avg3)
        diffP_21.append(avg2-avg1)
        diffP_22.append(avg3-avg2)
        print(n, avg1, avg2, avg2-avg1, avg3-avg2)
        
        n += 1

plt.figure()
plt.subplot(2,3,1)
plt.hist(firstP_2, 10)
plt.subplot(2,3,2)
plt.hist(secondP_2,10)
plt.subplot(2,3,3)
plt.hist(thirdP_2, 10)
plt.subplot(2,3,4)
plt.hist(diffP_21, 10)
plt.subplot(2,3,5)
plt.hist(diffP_22, 10)
plt.show()
# Out:
# 0 2.886803482850014e-07 -5.253309153704411e-08 -3.4121343982204553e-07 4.1348660738909385e-07
# 1 2.5688603881627416e-07 2.630678836502185e-08 -2.305792504512523e-07 4.0671472099530584e-07
# 2 3.210524706164192e-07 -1.816669226610376e-10 -3.2123413753908025e-07 3.520161058264613e-07
# 3 3.762453605682775e-07 8.103602583782535e-08 -2.952093347304521e-07 3.433909494798179e-07
# 4 2.488932254778845e-07 -2.617966473267983e-08 -2.7507289021056433e-07 3.6846339102484885e-07
# 5 3.1822522119333716e-07 3.200951809392054e-08 -2.8621570309941664e-07 3.5092594831580506e-07
# 6 3.66131227711376e-07 5.245221859037628e-08 -3.136790091209997e-07 3.573878606233359e-07

# %%
# %matplotlib inline
# Get the noise average for df_noise3

# P1: t1 = 0.0002, t2 = 0.0010
# P2: t1 = 0.01635, t2 = 0.01725

t1_1 = 0.0001
t1_2 = 0.0010
t2_1 = 0.01635
t2_2 = 0.01725
n = 0

firstP_3 = []
secondP_3 = []
diffP_3 = []

for sheet in df_noise3.keys():
    if sheet == 'Calc' or sheet == 'Settings':
        continue 
    else:
        dat1 = df_noise3[sheet][['TimeOutput','VMeasCh1','IMeasCh1']].to_numpy()

        idx1_1 = -1
        idx1_2 = -1
        idx2_1 = -1
        idx2_2 = -1
        
        for i in range(dat1.shape[0]):
            if dat1[i,0] >= t1_1 and dat1[i,0] < t1_2 and idx1_1 == -1:
                idx1_1 = i
            
            if dat1[i,0] >= t1_2 and idx1_2 == -1:
                idx1_2 = i

            if dat1[i,0] >= t2_1 and dat1[i,0] < t2_2 and idx2_1 == -1:
                idx2_1 = i

            if dat1[i,0] >= t2_2 and idx2_2 == -1:
                idx2_2 = i

        avg1 = np.average(dat1[idx1_1:idx1_2,2])
        avg2 = np.average(dat1[idx2_1:idx2_2,2])

        firstP_3.append(avg1)
        secondP_3.append(avg2)
        diffP_3.append(avg2-avg1)
        print(n, avg1, avg2, avg2-avg1)
        
        n += 1

plt.figure()
plt.subplot(1,3,1)
plt.hist(firstP_3, 10)
plt.subplot(1,3,2)
plt.hist(secondP_3,10)
plt.subplot(1,3,3)
plt.hist(diffP_3, 10)
plt.show()
# Out:
# 0 1.6763537609493905e-07 2.561578761390951e-07 8.852250004415606e-08
# 1 2.751339154957566e-07 3.6142983844141573e-07 8.629592294565914e-08
# 2 3.1017818736872025e-07 3.920412116429896e-07 8.186302427426935e-08
# 3 2.2663046772478247e-07 3.0409573689506487e-07 7.74652691702824e-08
# 4 2.830896123956451e-07 3.1129900737548096e-07 2.820939497983584e-08
# 5 2.7108575188442497e-07 2.8864611229886315e-07 1.7560360414438175e-08
# 6 3.5720399824527014e-07 4.4556365890893365e-07 8.835966066366351e-08
# 7 2.8828817422423947e-07 3.285705937493484e-07 4.0282419525108944e-08
# 8 2.499127562706147e-07 3.500491209614607e-07 1.0013636469084604e-07
# 9 2.452155644270934e-07 3.067974217403879e-07 6.158185731329447e-08
# 10 2.751148973590243e-07 3.379987737964707e-07 6.288387643744643e-08

# %% [markdown]
# # Collected Signals

# %%
# Sequence 6 on device (10,5)
pth = '/Users/jasonyuan/Desktop/Kherani Lab/Memristor/Keithley Data/Au Vertical/February 19/STDP_9V_6_10_5.xls'

df = pd.read_excel(pth, sheet_name=None)

t1_1 = 0.0001
t1_2 = 0.0010
t2_1 = 0.01635
t2_2 = 0.01725
n = 0

firstP = []
secondP = []
diffP = []

for sheet in df.keys():
    if sheet == 'Calc' or sheet == 'Settings':
        continue 
    else:
        dat1 = df[sheet][['TimeOutput','VMeasCh1','IMeasCh1']].to_numpy()

        idx1_1 = -1
        idx1_2 = -1
        idx2_1 = -1
        idx2_2 = -1
        
        for i in range(dat1.shape[0]):
            if dat1[i,0] >= t1_1 and dat1[i,0] < t1_2 and idx1_1 == -1:
                idx1_1 = i
            
            if dat1[i,0] >= t1_2 and idx1_2 == -1:
                idx1_2 = i

            if dat1[i,0] >= t2_1 and dat1[i,0] < t2_2 and idx2_1 == -1:
                idx2_1 = i

            if dat1[i,0] >= t2_2 and idx2_2 == -1:
                idx2_2 = i

        avg1 = np.average(dat1[idx1_1:idx1_2,2])
        avg2 = np.average(dat1[idx2_1:idx2_2,2])

        firstP.append(avg1)
        secondP.append(avg2)
        diffP.append(avg2-avg1)
        print(n, avg1, avg2, avg2-avg1)
        
        n += 1

plt.figure()
plt.subplot(1,3,1)
plt.hist(firstP, 10)
plt.subplot(1,3,2)
plt.hist(secondP,10)
plt.subplot(1,3,3)
plt.hist(diffP, 10)
plt.show()
# Out:
# WARNING *** file size (23776126) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# 0 2.7334646215030835e-07 3.1885258269497695e-07 4.55061205446686e-08
# 1 2.3618932666621687e-07 2.8388828520803517e-07 4.76989585418183e-08
# 2 2.0028469693823167e-07 3.232823020655725e-07 1.229976051273408e-07
# 3 2.838826162752716e-07 3.659973177001847e-07 8.211470142491306e-08
# 4 2.7950827863010134e-07 3.133816337348348e-07 3.387335510473347e-08
# 5 2.6180269400303784e-07 3.6587200404689857e-07 1.0406931004386073e-07
# 6 2.756296272158706e-07 2.9462988641121776e-07 1.900025919534717e-08
# 7 1.9235284208681623e-07 2.753146581892957e-07 8.296181610247949e-08
# 8 2.111157049650738e-07 2.247510480148727e-07 1.3635343049798896e-08
# 9 2.1354172909327703e-07 3.0370343741353416e-07 9.016170832025713e-08
# 10 3.0328641317419383e-07 3.637527044121246e-07 6.046629123793076e-08
# ...

# %%
# Sequence 7 on device (10,5)
pth = '/Users/jasonyuan/Desktop/Kherani Lab/Memristor/Keithley Data/Au Vertical/February 19/STDP_10V_7_10_5.xls'

df = pd.read_excel(pth, sheet_name=None)

t1_1 = 0.0001
t1_2 = 0.0010
t2_1 = 0.01635
t2_2 = 0.01725
n = 0

firstP = []
secondP = []
diffP = []

for sheet in df.keys():
    if sheet == 'Calc' or sheet == 'Settings':
        continue 
    else:
        dat1 = df[sheet][['TimeOutput','VMeasCh1','IMeasCh1']].to_numpy()

        idx1_1 = -1
        idx1_2 = -1
        idx2_1 = -1
        idx2_2 = -1
        
        for i in range(dat1.shape[0]):
            if dat1[i,0] >= t1_1 and dat1[i,0] < t1_2 and idx1_1 == -1:
                idx1_1 = i
            
            if dat1[i,0] >= t1_2 and idx1_2 == -1:
                idx1_2 = i

            if dat1[i,0] >= t2_1 and dat1[i,0] < t2_2 and idx2_1 == -1:
                idx2_1 = i

            if dat1[i,0] >= t2_2 and idx2_2 == -1:
                idx2_2 = i

        avg1 = np.average(dat1[idx1_1:idx1_2,2])
        avg2 = np.average(dat1[idx2_1:idx2_2,2])

        firstP.append(avg1)
        secondP.append(avg2)
        diffP.append(avg2-avg1)
        print(n, avg1, avg2, avg2-avg1)
        
        n += 1

plt.figure()
plt.subplot(1,3,1)
plt.hist(firstP, 10)
plt.subplot(1,3,2)
plt.hist(secondP,10)
plt.subplot(1,3,3)
plt.hist(diffP, 10)
plt.show()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# 0 3.314414531680114e-07 3.8202075712139943e-07 5.0579303953388025e-08
# 1 2.472160291719485e-07 3.2766439116592645e-07 8.044836199397796e-08
# 2 2.5788308899196405e-07 3.598536739936929e-07 1.0197058500172886e-07
# 3 3.387627510613297e-07 3.893878308345599e-07 5.0625079773230186e-08
# 4 3.487117678249971e-07 3.846773411334889e-07 3.596557330849184e-08
# 5 2.544489673532846e-07 3.185458722330918e-07 6.409690487980718e-08
# 6 2.2377174695812005e-07 2.752738715720357e-07 5.150212461391567e-08
# 7 2.969455228279842e-07 3.498839879847504e-07 5.29384651567662e-08
# 8 2.785405805648585e-07 3.299978084868866e-07 5.145722792202809e-08
# 9 3.2466240519986117e-07 3.7283594515259966e-07 4.817353995273849e-08
# 10 2.941292378003194e-07 3.4624165569468595e-07 5.2112417894366565e-08

# %%
# Sequence 8 on device (10,5)
pth = '/Users/jasonyuan/Desktop/Kherani Lab/Memristor/Keithley Data/Au Vertical/February 19/STDP_10V_8_10_5.xls'

df = pd.read_excel(pth, sheet_name=None)

t1_1 = 0.0001
t1_2 = 0.0010
t2_1 = 0.02138
t2_2 = 0.02225
n = 0

firstP = []
secondP = []
diffP = []

for sheet in df.keys():
    if sheet == 'Calc' or sheet == 'Settings':
        continue 
    else:
        dat1 = df[sheet][['TimeOutput','VMeasCh1','IMeasCh1']].to_numpy()

        idx1_1 = -1
        idx1_2 = -1
        idx2_1 = -1
        idx2_2 = -1
        
        for i in range(dat1.shape[0]):
            if dat1[i,0] >= t1_1 and dat1[i,0] < t1_2 and idx1_1 == -1:
                idx1_1 = i
            
            if dat1[i,0] >= t1_2 and idx1_2 == -1:
                idx1_2 = i

            if dat1[i,0] >= t2_1 and dat1[i,0] < t2_2 and idx2_1 == -1:
                idx2_1 = i

            if dat1[i,0] >= t2_2 and idx2_2 == -1:
                idx2_2 = i

        avg1 = np.average(dat1[idx1_1:idx1_2,2])
        avg2 = np.average(dat1[idx2_1:idx2_2,2])

        firstP.append(avg1)
        secondP.append(avg2)
        diffP.append(avg2-avg1)
        print(n, avg1, avg2, avg2-avg1)
        
        n += 1

plt.figure()
plt.subplot(1,3,1)
plt.hist(firstP, 10)
plt.subplot(1,3,2)
plt.hist(secondP,10)
plt.subplot(1,3,3)
plt.hist(diffP, 10)
plt.show()
# Out:
# WARNING *** file size (17918644) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# 0 3.093869578663089e-07 3.2910182145150704e-07 1.9714863585198143e-08
# 1 3.152578520015936e-07 3.202722445528635e-07 5.014392551269914e-09
# 2 2.652536954070306e-07 3.5866713695300726e-07 9.341344154597666e-08
# 3 2.8029210123126093e-07 3.3561202824542454e-07 5.5319927014163603e-08
# 4 2.2704183891164576e-07 3.078084341856524e-07 8.076659527400665e-08
# 5 2.2836547775684223e-07 2.992449412777738e-07 7.087946352093158e-08
# 6 2.382913651644003e-07 2.52603316896969e-07 1.431195173256871e-08
# 7 2.57765101903118e-07 3.256498757285744e-07 6.788477382545642e-08
# 8 2.742668168309592e-07 2.548261193514457e-07 -1.9440697479513512e-08
# 9 2.8024819942018553e-07 3.1417472171101204e-07 3.392652229082651e-08
# 10 2.0598196584842298e-07 1.9715728160713533e-07 -8.824684241287651e-09
# ...

# %%
# Sequence 7 on device (9,10)
pth = '/Users/jasonyuan/Desktop/Kherani Lab/Memristor/Keithley Data/Au Vertical/February 19/STDP_10V_7_9_10.xls'

df = pd.read_excel(pth, sheet_name=None)

t1_1 = 0.0001
t1_2 = 0.0010
t2_1 = 0.01635
t2_2 = 0.01725
n = 0

firstP = []
secondP = []
diffP = []

for sheet in df.keys():
    if sheet == 'Calc' or sheet == 'Settings':
        continue 
    else:
        dat1 = df[sheet][['TimeOutput','VMeasCh1','IMeasCh1']].to_numpy()

        idx1_1 = -1
        idx1_2 = -1
        idx2_1 = -1
        idx2_2 = -1
        
        for i in range(dat1.shape[0]):
            if dat1[i,0] >= t1_1 and dat1[i,0] < t1_2 and idx1_1 == -1:
                idx1_1 = i
            
            if dat1[i,0] >= t1_2 and idx1_2 == -1:
                idx1_2 = i

            if dat1[i,0] >= t2_1 and dat1[i,0] < t2_2 and idx2_1 == -1:
                idx2_1 = i

            if dat1[i,0] >= t2_2 and idx2_2 == -1:
                idx2_2 = i

        avg1 = np.average(dat1[idx1_1:idx1_2,2])
        avg2 = np.average(dat1[idx2_1:idx2_2,2])

        firstP.append(avg1)
        secondP.append(avg2)
        diffP.append(avg2-avg1)
        print(n, avg1, avg2, avg2-avg1)
        
        n += 1

plt.figure()
plt.subplot(1,3,1)
plt.hist(firstP, 10)
plt.subplot(1,3,2)
plt.hist(secondP,10)
plt.subplot(1,3,3)
plt.hist(diffP, 10)
plt.show()
# Out:
# WARNING *** file size (6941566) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# 0 2.645369470762948e-07 3.099016345979226e-07 4.536468752162781e-08
# 1 2.698494627969885e-07 3.7328529699653496e-07 1.0343583419954646e-07
# 2 2.63029567302746e-07 3.3069827020860896e-07 6.766870290586296e-08
# 3 2.4838340119863124e-07 3.377294561373876e-07 8.934605493875637e-08
# 4 2.628167955880351e-07 3.096992089094181e-07 4.688241332138301e-08
# 5 2.743442209105118e-07 3.2953489746724777e-07 5.5190676556735986e-08

# %% [markdown]
# # STDP Analysis

# %%
def analysis3(input_file=None,t_min=None,t_max=None,filter=False):
    # Function for determining resistance of the combined spike waveform train
    if input_file == None:
        file_to_use = "/Users/jasonyuan/Desktop/Kherani Lab/Memristor/Keithley Data/Jason - 24mtorr Vertical Crossbar/Block 1/Dec 7/Pulse_Before_5_7_Combined.xls"
    else:
        file_to_use = input_file

    data = pd.read_excel(file_to_use,sheet_name="Data")
    sub_data = data.filter(items=["TimeOutput","IMeasCh1","VMeasCh1"]).to_numpy()   # Change CH1 according to needle descriptions
    nrows,ncols = sub_data.shape

    if (t_min == None) or (t_max == None):
        t_min = 0.2*10**(-5)
        t_max = 0.8*10**(-5)

    current_avg = 0
    voltage_avg = 0
    cum_R = 0
    n_points = 0

    if not filter:
        for r in range(0,nrows):
            if (sub_data[r,0] > t_min) and (sub_data[r,0] < t_max):
                current_avg += sub_data[r,1]
                voltage_avg += sub_data[r,2]
                cum_R += abs(voltage_avg/current_avg)
                n_points += 1

        current_avg = abs(current_avg/n_points)
        voltage_avg = abs(voltage_avg/n_points)

        R_avg = voltage_avg/current_avg
        # R_avg = cum_R/n_points

    else:
        current_array = []
        voltage_array = []
        for r in range(0,nrows):
            if (sub_data[r,0] > t_min) and (sub_data[r,0] < t_max):
                current_array.append(sub_data[r,1])
                voltage_array.append(sub_data[r,2])
                n_points += 1

        filtered_current = sg.savgol_filter(x=current_array,window_length=13,polyorder=1,deriv=0)
        filtered_voltage = sg.savgol_filter(x=voltage_array,window_length=13,polyorder=1,deriv=0)

        for n in range(len(filtered_current)):
            cum_R += abs(filtered_voltage[n]/filtered_current[n])

        current_avg = abs(sum(filtered_current)/n_points)
        voltage_avg = abs(sum(filtered_voltage)/n_points)

        # R_avg = voltage_avg/current_avg
        R_avg = cum_R/n_points

    print(n_points)
    print("Current: {}".format(current_avg))
    print("Voltage: {}".format(voltage_avg))
    print("Resistance: {}".format(R_avg))
    print("----------------------------------------------------------------")

    return current_avg,voltage_avg,R_avg

def synaptic_weight_calc(R_before,R_after,R_min):
    delta_w = (1/R_after-1/R_before)/(1/R_min)*100
    return delta_w

# %%
def synaptic_weight_combined_analysis(t_file,input_file,save_dir,reverse=True,filter=False):
    # Analysis function for the combined spike waveform, manually have to go
    # through and determine the time intervals

    if not os.path.isdir(save_dir):
        os.makedirs(save_dir)

    data_times = pd.read_excel(t_file) # Columns will be t_min,t_max
    rows,cols = data_times.shape

    new_data = {}
    delta_T = [0]
    R_before = []
    R_after = []
    delta_w = []
    R_min = np.inf

    for i in range(5,65,5):
        if not reverse:
            delta_T.append(i)
            delta_T.append(-i)
        else:
            delta_T.append(-i)
            delta_T.append(i)
    for i in range(70,110,10):
        if not reverse:
            delta_T.append(i)
            delta_T.append(-i)
        else:
            delta_T.append(-i)
            delta_T.append(i)
    new_data["delta_T"] = delta_T

    for idx in range(0,rows):          # Modify for separate pulse_before
        t_min = data_times.iloc[idx]["t_min"]
        t_max = data_times.iloc[idx]["t_max"]

        if (t_min == -1) and (t_max == -1):
            I,V,R = analysis3()
        else:
            I,V,R = analysis3(input_file,t_min,t_max,filter)

        R_min = min(R,R_min)

        if (idx == 0):
            R_before.append(R)
        elif (idx == rows-1):
            R_after.append(R)
        else:
            R_before.append(R)
            R_after.append(R)
    new_data["R_before"] = R_before
    new_data["R_after"] = R_after
    new_data["R_min"] = R_min

    for n in range(0,len(R_before)):
        w_instance = synaptic_weight_calc(R_before[n],R_after[n],R_min)
        delta_w.append(w_instance)
    new_data["delta_w"] = delta_w

    filename = input_file.split("/")[len(input_file.split("/"))-1].split(".")[0]
    df_newdata = pd.DataFrame(new_data)
    df_newdata = df_newdata.sort_values(by="delta_T",axis=0)
    df_newdata.to_csv(save_dir+"/"+"Processed_{}.csv".format(filename))

    fig = plt.figure()
    ax = fig.add_subplot(1,1,1,label="1")
    ax.scatter(delta_T,delta_w,color="cornflowerblue",label="Synaptic Weight")
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.set_xlabel('ΔT (μs)',color='k')
    ax.set_ylabel('∆w%', color='cornflowerblue')
    ax.tick_params(axis='x', which='both', labelcolor='k')
    ax.tick_params(axis='y', which='both', labelcolor='cornflowerblue')

    ax.grid(linestyle="--",color="silver")
    ax.set_title(filename)
    fig.tight_layout()

    fig.savefig(save_dir+"/"+'{}_∆w_plot.png'.format(filename),bbox_inches='tight',format='png',dpi=600)
    plt.close(fig)

    print("Finished processing {}".format(filename))
    return True

# %%
# %matplotlib inline

t_file = "/Users/jasonyuan/Desktop/Kherani Lab/Memristor/STDP_Au_Time_Range.xlsx"
save_dir = "/Users/jasonyuan/Desktop/STDP_40mTorr_Noise"
# save_base = "/Users/jasonyuan/Desktop/Kherani Lab/Memristor/Cleaned Data/14mTorr/Block 1/Cleaned Plots"
input_file = "/Users/jasonyuan/Desktop/Kherani Lab/Memristor/Keithley Data/Au Vertical/February 27/10 uA scale/Noise/STDP_10V_Full_Noise.xls"

synaptic_weight_combined_analysis(t_file,input_file,save_dir,reverse=False,filter=False)
# Out:
# 35
# Current: 5.77262534916047e-09
# Voltage: 3.9979941844940186
# Resistance: 692578149.9184697
# ----------------------------------------------------------------
# 23
# Current: 1.2358558426326673e-09
# Voltage: 3.995300479557203
# Resistance: 3232820804.6063538
# ----------------------------------------------------------------
# 35
# Current: 2.502444227580772e-09
# Voltage: 3.992198099408831
# Resistance: 1595319510.1847575
# ----------------------------------------------------------------
# 35
# Current: 2.4727422522892846e-09
# Voltage: 3.991020917892456
# Resistance: 1614006034.877892
# ----------------------------------------------------------------
# 36
# Current: 2.2327517185858793e-09
# Voltage: 3.9885922604136996
# Resistance: 1786402055.9078946
# ----------------------------------------------------------------
# 36
# Current: 4.666306283503581e-09
# Voltage: 3.9863450858328076
# Resistance: 854282776.063246
# ...

# %% [markdown]
# ## Averaging trials for each device

# %%
dir = '/Users/jasonyuan/Desktop/Kherani Lab/Memristor/STDP/Au Vertical/40mTorr_10uA/STDP_40mTorr_Noise'

avg_dw = np.zeros(33)
n = 0
for file in os.listdir(dir):
    if file.endswith('csv'):
        df = pd.read_csv(dir+'/'+file)
        df_dw = df['delta_w'].to_numpy()

        avg_dw = avg_dw + df_dw
        n += 1
avg_dw = avg_dw/n
delta_t = df['delta_T'].to_numpy()

# avg_dw = avg_dw.reshape((-1,1))
# delta_t = delta_t.reshape((-1,1))

data_combined = {'delta_T': delta_t, 'delta_w': avg_dw}
df_combined = pd.DataFrame(data_combined)

# print(n, data_combined)

# %matplotlib inline
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(1,1,1)
ax.scatter(delta_t, avg_dw)

ax.grid(color='silver',linestyle='--')
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.tick_params(axis='x', which='both', labelcolor='k')
ax.tick_params(axis='y', which='both', labelcolor='k')

ax.set_xlabel('ΔT (μs)',color='k')
ax.set_ylabel('∆w%', color='k')
ax.set_title('STDP_40mTorr_Noise')

plt.show()

fig.savefig(dir+"/"+'{}_∆w_plot.png'.format('STDP_40mTorr_Noise'),bbox_inches='tight',format='png',dpi=600)
df_combined.to_csv(dir+'/'+'Averaged.csv')
